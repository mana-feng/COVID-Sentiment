# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
from transformers import DistilBertTokenizerFast 
from scipy.stats import poisson

dataset = pd.read_csv("../../clean_COVIDSenti.csv")
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

def tokenize(tweet):
    tokenized = tokenizer(tweet, return_tensors='pt', padding="max_length", max_length = 47) #Max tweet token length is 47
    return tokenized

tweets, labels = dataset['tweet'], dataset['label']
labels = [l + 1 for l in labels]
tokenized_tweets = tweets.map(tokenize)
tokenized_tweets = tokenized_tweets.to_list()
vocab_size = max(map(lambda x: torch.max(x['input_ids']), tokenized_tweets)).item() + 1
max_len = max(map(lambda x: len(x['input_ids']), tokenized_tweets))

#Determining correct backend
def get_device():
    # Check Intel XPU
    try:
        import intel_extension_for_pytorch as ipex
        if hasattr(torch, 'xpu') and torch.xpu.is_available():
            device = torch.device("xpu")
            print(f"Training on Intel XPU: {torch.xpu.get_device_name(0)}")
            return device
    except (ImportError, OSError) as e:
        print(f"Intel XPU not available: {e}")
        pass
    
    # Check Apple MPS
    if torch.backends.mps.is_available():
        device = torch.device("mps")
        print("Training on Apple GPU (MPS)")
        return device
    
    # Check NVIDIA CUDA
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print(f"Training on NVIDIA CUDA: {torch.cuda.get_device_name(0)}")
        return device
    
    # Check OpenVINO NPU
    try:
        import openvino as ov
        core = ov.Core()
        available_devices = core.available_devices
        if 'NPU' in available_devices:
            print(f"OpenVINO NPU available: {core.get_property('NPU', 'DEVICE_FULL_NAME')}")
    except:
        pass
    
    # Fallback to CPU
    print("Training on CPU")
    return torch.device("cpu")

device = get_device()
print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")
# Out:
# Intel XPU not available: No module named 'intel_extension_for_pytorch'
# Training on NVIDIA CUDA: NVIDIA GeForce RTX 4080 SUPER
# PyTorch version: 2.7.0+cu128
# Device: cuda

# %%
class PositionalEncoding(nn.Module):
    #Class used to encode positions
    def __init__(self, embedding_dim, max_len):
        super(PositionalEncoding, self).__init__()
        
        pe = torch.zeros(max_len, embedding_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, embedding_dim, 2).float() * (-np.log(10000.0) / embedding_dim))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe) #Ensures that this positional encoding isn't updated by the optimizer

    def forward(self, x):
        return x + self.pe

class SentimentTransformer(nn.Module):
    def __init__(self, vocab_size, output_size, embedding_dim, prelude_layers, poisson_mean, coda_layers,
                 nhead = 4, dropout = 0.1, exit_threshold = 1e-4):
        super().__init__()
        self.vocab_size = vocab_size
        self.output_size = output_size
        self.embedding_dim = embedding_dim
        self.prelude_layers = prelude_layers
        self.coda_layers = coda_layers
        self.poisson_mean = poisson_mean
        self.exit_threshold = exit_threshold
        
        self.pe = PositionalEncoding(embedding_dim=embedding_dim, max_len=max_len)
        self.embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim)
        self.prelude_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(embedding_dim, nhead = nhead, dropout=dropout, batch_first=True)
            for _ in range(prelude_layers)
        ])
        
        self.recurrent_layer = nn.TransformerEncoderLayer(embedding_dim, nhead=nhead, dropout=0.1, batch_first=True)

        self.coda_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(embedding_dim, nhead = nhead, dropout=dropout, batch_first=True)
            for _ in range(coda_layers)
        ])
        
        self.lin = nn.Linear(embedding_dim, output_size)

    def forward(self, input_ids, attention_mask):
        attention_mask = ~attention_mask.bool()
        output = self.embedding(input_ids)
        output = self.pe(output)
        for layer in self.prelude_layers:
            output = layer(output, src_key_padding_mask = attention_mask)
        
        prev_output = output
        recurrences = poisson.rvs(self.poisson_mean, size = 1)
        for _ in range(recurrences[0]):
            output = self.recurrent_layer(output, src_key_padding_mask = attention_mask)
            diff = torch.mean(torch.norm(output - prev_output, p=2, dim=-1))
            if diff < self.exit_threshold:
                # Early exit if the change is small enough
                break
            prev_output = output
        
        for layer in self.coda_layers:
            output = layer(output, src_key_padding_mask = attention_mask)
        
        output = output.mean(axis = 1)
        output = self.lin(output)
        return output

# %%
from torch.utils.data import DataLoader, WeightedRandomSampler, Dataset, random_split

class TweetDataset(Dataset):
    def __init__(self, tweets, labels):
        self.x = tweets
        self.y = labels
        
    def __getitem__(self, index):
        # Check that x is really a dictionary before processing
        x = self.x[index]
        x = dict(x)
        x = {key: torch.squeeze(val, dim = 0) for key, val in x.items()}
        y = self.y[index]
        return (x, y)
    
    def __len__(self):
        return len(self.x)
    
folds = 5
early_stopping = 5 #Stop if 5 epochs without improvement on val
train_frac = 0.8
test_frac = 0.1
val_frac = 0.1
batch_size = 64
test_accuracies = []
data = TweetDataset(tokenized_tweets, labels)

#Instantiating model
dropout = 0.5
nhead = 8
output_size = 3
embedding_dim = 128
prelude_layers = 1
coda_layers = 1
poisson_mean = 3

for fold in range(folds):
    
    model = SentimentTransformer(
    vocab_size=vocab_size, 
    output_size=output_size, 
    embedding_dim=embedding_dim, 
    prelude_layers=prelude_layers, 
    coda_layers=coda_layers, 
    poisson_mean=poisson_mean,
    nhead = nhead, 
    dropout = dropout)
    
    print(f"FOLD {fold}")
    gen = torch.Generator().manual_seed(fold)
    train, val, test = random_split(data, lengths=[train_frac, val_frac, test_frac], generator=gen)
    
    #Dealing with imbalanced class weights for train dataset
    labels_for_counts = list(map(lambda x: x[-1], train))
    frequency = 1 / np.bincount(labels_for_counts)
    class_weights = torch.tensor(frequency, dtype=torch.float32)
    obs_weights = list(map(lambda x: class_weights[x[-1]], train))
        
    train_sampler = WeightedRandomSampler(weights = obs_weights, num_samples = len(obs_weights))
    train_loader = DataLoader(train, batch_size=batch_size, sampler=train_sampler)
    val_loader = DataLoader(val, shuffle=False, batch_size=batch_size)
    test_loader = DataLoader(test, shuffle=False, batch_size=batch_size)
    
    #---- TRAINING ACTUAL MODEL FROM HERE ON OUT ----#
    model = model.to(device)
    model.train()

    lr = 0.0001
    epoch = 0
    no_improvement = 0
    curr_acc = 0
    criterion = nn.CrossEntropyLoss() #Without softmax we use CEL
    optimizer = torch.optim.AdamW(model.parameters(), lr = lr)
    scaler = torch.amp.GradScaler(device.type)

    while no_improvement < early_stopping:
        epoch += 1
        print(f"Epoch {epoch}")
        
        #Training model layers
        for train_inputs, train_labels in train_loader:
            train_inputs['input_ids'], train_inputs['attention_mask'] = train_inputs['input_ids'].to(device), train_inputs['attention_mask'].to(device)
            train_labels = train_labels.to(device)
            
            model.zero_grad()
            with torch.autocast(device.type):
                output = model(**train_inputs)
                loss = criterion(output, train_labels.long())
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
        
        #Early stopping
        model.eval()
        correct = torch.tensor(0, device = device)
        incorrect = torch.tensor(0, device = device)
        corrects = torch.zeros(3, device = device)
        incorrects = torch.zeros(3, device = device)
        
        with torch.no_grad():
            for val_inputs, val_labels in val_loader:
                val_inputs['input_ids'], val_inputs['attention_mask'] = val_inputs['input_ids'].to(device), val_inputs['attention_mask'].to(device)
                val_labels = val_labels.to(device)
                probs = model(**val_inputs)
                preds = torch.argmax(probs, axis = 1)
                correct += (preds == val_labels).sum()
                incorrect += (preds != val_labels).sum()  
                for idx in range(3):
                    corrects[idx] += ((preds == val_labels) & (val_labels == idx)).sum() 
                    incorrects[idx] += ((preds != val_labels) & (val_labels == idx)).sum() 
        
        accuracy = correct / (correct + incorrect)
        val_accuracy_each = corrects / (corrects + incorrects)
        print(f"Accuracies: {val_accuracy_each}")
        if accuracy > curr_acc:
            
            print(f"New accuracy has been reached: {accuracy}")
            curr_acc = accuracy
            no_improvement = 0
        else:
            no_improvement += 1
        
        model.train()
        
    model.eval()
    corrects = torch.zeros(3, device = device)
    incorrects = torch.zeros(3, device = device)
    
    correct = torch.tensor(0, device = device)
    incorrect = torch.tensor(0, device = device)
    
    #Getting test accuracy for CV purposes
    with torch.no_grad():
        for test_inputs, test_labels in test_loader:
            test_inputs['input_ids'], test_inputs['attention_mask'] = test_inputs['input_ids'].to(device), test_inputs['attention_mask'].to(device)
            test_labels = test_labels.to(device)
            probs = model(**test_inputs)
            preds = torch.argmax(probs, axis = 1)
            correct += (preds == test_labels).sum()
            incorrect += (preds != test_labels).sum()  
            for idx in range(3):
                corrects[idx] += ((preds == test_labels) & (test_labels == idx)).sum() 
                incorrects[idx] += ((preds != test_labels) & (test_labels == idx)).sum() 
    
    test_accuracy = correct / (correct + incorrect)
    test_accuracy_each = corrects / (corrects + incorrects)
    test_accuracies.append(test_accuracy)
    print(f"FOR FOLD {fold}, THE TEST ACCURACY WAS {test_accuracy}")
    print(f"FOR FOLD {fold}, THE ACCURACIES WERE {test_accuracy_each}")
    print("---------------------------------------")
# Out:
# FOLD 0
# Epoch 1
# Accuracies: tensor([0.6480, 0.7593, 0.6636], device='cuda:0')
# New accuracy has been reached: 0.733222246170044
# Epoch 2
# Accuracies: tensor([0.7376, 0.8280, 0.7318], device='cuda:0')
# New accuracy has been reached: 0.8055555820465088
# Epoch 3
# Accuracies: tensor([0.7524, 0.8526, 0.7504], device='cuda:0')
# New accuracy has been reached: 0.828000009059906
# Epoch 4
# Accuracies: tensor([0.8079, 0.7557, 0.8248], device='cuda:0')
# Epoch 5
# Accuracies: tensor([0.7576, 0.8001, 0.8388], device='cuda:0')
# Epoch 6
# Accuracies: tensor([0.8285, 0.7725, 0.8310], device='cuda:0')
# Epoch 7
# Accuracies: tensor([0.8137, 0.7916, 0.8202], device='cuda:0')
# Epoch 8
# Accuracies: tensor([0.8137, 0.8191, 0.8140], device='cuda:0')
# FOR FOLD 0, THE TEST ACCURACY WAS 0.8169999718666077
# FOR FOLD 0, THE ACCURACIES WERE tensor([0.8114, 0.8198, 0.8006], device='cuda:0')
# ---------------------------------------
# FOLD 1
# Epoch 1
# Accuracies: tensor([0.5870, 0.8039, 0.6617], device='cuda:0')
# New accuracy has been reached: 0.7540000081062317
# Epoch 2
# Accuracies: tensor([0.7525, 0.7858, 0.7141], device='cuda:0')
# New accuracy has been reached: 0.7744444608688354
# Epoch 3
# Accuracies: tensor([0.7328, 0.8254, 0.7515], device='cuda:0')
# New accuracy has been reached: 0.8031111359596252
# Epoch 4
# Accuracies: tensor([0.7586, 0.8454, 0.7365], device='cuda:0')
# New accuracy has been reached: 0.8215555548667908
# Epoch 5
# Accuracies: tensor([0.7525, 0.8652, 0.7320], device='cuda:0')
# New accuracy has been reached: 0.8348888754844666
# Epoch 6
# Accuracies: tensor([0.8113, 0.7494, 0.8114], device='cuda:0')
# Epoch 7
# Accuracies: tensor([0.8266, 0.8197, 0.7665], device='cuda:0')
# Epoch 8
# Accuracies: tensor([0.8211, 0.8276, 0.7605], device='cuda:0')
# Epoch 9
# Accuracies: tensor([0.8266, 0.8088, 0.7710], device='cuda:0')
# Epoch 10
# Accuracies: tensor([0.8456, 0.8554, 0.7305], device='cuda:0')
# New accuracy has been reached: 0.8443333506584167
# Epoch 11
# Accuracies: tensor([0.8192, 0.8693, 0.7305], device='cuda:0')
# New accuracy has been reached: 0.8498888611793518
# Epoch 12
# Accuracies: tensor([0.8468, 0.8122, 0.7710], device='cuda:0')
# Epoch 13
# Accuracies: tensor([0.8309, 0.8303, 0.7515], device='cuda:0')
# Epoch 14
# Accuracies: tensor([0.8321, 0.8548, 0.7440], device='cuda:0')
# Epoch 15
# Accuracies: tensor([0.8640, 0.8561, 0.7231], device='cuda:0')
# Epoch 16
# Accuracies: tensor([0.8738, 0.8419, 0.7021], device='cuda:0')
# FOR FOLD 1, THE TEST ACCURACY WAS 0.8424444198608398
# FOR FOLD 1, THE ACCURACIES WERE tensor([0.8892, 0.8437, 0.7067], device='cuda:0')
# ---------------------------------------
# FOLD 2
# Epoch 1
# Accuracies: tensor([0.7574, 0.6414, 0.6609], device='cuda:0')
# New accuracy has been reached: 0.6636666655540466
# Epoch 2
# Accuracies: tensor([0.7685, 0.7849, 0.7256], device='cuda:0')
# New accuracy has been reached: 0.7777777910232544
# Epoch 3
# Accuracies: tensor([0.8160, 0.8137, 0.7350], device='cuda:0')
# New accuracy has been reached: 0.808555543422699
# Epoch 4
# Accuracies: tensor([0.8525, 0.7742, 0.7603], device='cuda:0')
# Epoch 5
# Accuracies: tensor([0.8352, 0.7390, 0.8186], device='cuda:0')
# Epoch 6
# Accuracies: tensor([0.8407, 0.8458, 0.7476], device='cuda:0')
# New accuracy has been reached: 0.8379999995231628
# Epoch 7
# Accuracies: tensor([0.8432, 0.7699, 0.8155], device='cuda:0')
# Epoch 8
# Accuracies: tensor([0.8926, 0.7659, 0.7886], device='cuda:0')
# Epoch 9
# Accuracies: tensor([0.8914, 0.8246, 0.7350], device='cuda:0')
# Epoch 10
# Accuracies: tensor([0.8772, 0.7990, 0.7808], device='cuda:0')
# Epoch 11
# Accuracies: tensor([0.8858, 0.8277, 0.7555], device='cuda:0')
# FOR FOLD 2, THE TEST ACCURACY WAS 0.8266666531562805
# FOR FOLD 2, THE ACCURACIES WERE tensor([0.8793, 0.8191, 0.7730], device='cuda:0')
# ---------------------------------------
# FOLD 3
# Epoch 1
# Accuracies: tensor([0.5692, 0.8108, 0.6057], device='cuda:0')
# New accuracy has been reached: 0.7531111240386963
# Epoch 2
# Accuracies: tensor([0.7425, 0.7407, 0.7504], device='cuda:0')
# Epoch 3
# Accuracies: tensor([0.7010, 0.7459, 0.8153], device='cuda:0')
# Epoch 4
# Accuracies: tensor([0.7810, 0.8247, 0.7504], device='cuda:0')
# New accuracy has been reached: 0.8117777705192566
# Epoch 5
# Accuracies: tensor([0.7871, 0.8260, 0.7621], device='cuda:0')
# New accuracy has been reached: 0.8146666884422302
# Epoch 6
# Accuracies: tensor([0.7877, 0.8083, 0.7837], device='cuda:0')
# Epoch 7
# Accuracies: tensor([0.7987, 0.8454, 0.7604], device='cuda:0')
# New accuracy has been reached: 0.8312222361564636
# Epoch 8
# Accuracies: tensor([0.8194, 0.7962, 0.7854], device='cuda:0')
# Epoch 9
# Accuracies: tensor([0.8005, 0.8382, 0.7837], device='cuda:0')
# Epoch 10
# Accuracies: tensor([0.8340, 0.8262, 0.7804], device='cuda:0')
# Epoch 11
# Accuracies: tensor([0.8261, 0.7930, 0.8053], device='cuda:0')
# Epoch 12
# Accuracies: tensor([0.8420, 0.8470, 0.7488], device='cuda:0')
# New accuracy has been reached: 0.839555561542511
# Epoch 13
# Accuracies: tensor([0.8420, 0.8206, 0.7820], device='cuda:0')
# Epoch 14
# Accuracies: tensor([0.8249, 0.8713, 0.7421], device='cuda:0')
# New accuracy has been reached: 0.8542222380638123
# Epoch 15
# Accuracies: tensor([0.8347, 0.8484, 0.7421], device='cuda:0')
# Epoch 16
# Accuracies: tensor([0.7584, 0.8791, 0.7587], device='cuda:0')
# Epoch 17
# Accuracies: tensor([0.8267, 0.8697, 0.7621], device='cuda:0')
# New accuracy has been reached: 0.8546666502952576
# Epoch 18
# Accuracies: tensor([0.8145, 0.8712, 0.7371], device='cuda:0')
# Epoch 19
# Accuracies: tensor([0.8188, 0.8707, 0.7371], device='cuda:0')
# Epoch 20
# Accuracies: tensor([0.8084, 0.8772, 0.7354], device='cuda:0')
# New accuracy has been reached: 0.855222225189209
# Epoch 21
# Accuracies: tensor([0.8444, 0.8698, 0.7288], device='cuda:0')
# New accuracy has been reached: 0.8557778000831604
# Epoch 22
# Accuracies: tensor([0.8072, 0.8809, 0.7238], device='cuda:0')
# New accuracy has been reached: 0.8569999933242798
# Epoch 23
# Accuracies: tensor([0.8249, 0.8922, 0.7155], device='cuda:0')
# New accuracy has been reached: 0.8681111335754395
# Epoch 24
# Accuracies: tensor([0.7785, 0.8846, 0.7238], device='cuda:0')
# Epoch 25
# Accuracies: tensor([0.8011, 0.8852, 0.7454], device='cuda:0')
# Epoch 26
# Accuracies: tensor([0.8298, 0.8950, 0.7155], device='cuda:0')
# New accuracy has been reached: 0.8711110949516296
# Epoch 27
# Accuracies: tensor([0.8176, 0.8808, 0.7421], device='cuda:0')
# Epoch 28
# Accuracies: tensor([0.8377, 0.8954, 0.7121], device='cuda:0')
# New accuracy has been reached: 0.8726666569709778
# Epoch 29
# Accuracies: tensor([0.8182, 0.8691, 0.7488], device='cuda:0')
# Epoch 30
# Accuracies: tensor([0.7755, 0.8978, 0.7488], device='cuda:0')
# Epoch 31
# Accuracies: tensor([0.8066, 0.8765, 0.7521], device='cuda:0')
# Epoch 32
# Accuracies: tensor([0.8322, 0.8848, 0.6955], device='cuda:0')
# Epoch 33
# Accuracies: tensor([0.8121, 0.8811, 0.7471], device='cuda:0')
# FOR FOLD 3, THE TEST ACCURACY WAS 0.8622221946716309
# FOR FOLD 3, THE ACCURACIES WERE tensor([0.8157, 0.8830, 0.7666], device='cuda:0')
# ---------------------------------------
# FOLD 4
# Epoch 1
# Accuracies: tensor([0.6961, 0.6589, 0.7617], device='cuda:0')
# New accuracy has been reached: 0.6733333468437195
# Epoch 2
# Accuracies: tensor([0.7452, 0.8182, 0.7345], device='cuda:0')
# New accuracy has been reached: 0.7986666560173035
# Epoch 3
# Accuracies: tensor([0.7918, 0.8066, 0.7421], device='cuda:0')
# New accuracy has been reached: 0.7991111278533936
# Epoch 4
# Accuracies: tensor([0.7839, 0.7734, 0.8009], device='cuda:0')
# Epoch 5
# Accuracies: tensor([0.8184, 0.8159, 0.7602], device='cuda:0')
# New accuracy has been reached: 0.8122222423553467
# Epoch 6
# Accuracies: tensor([0.8329, 0.8052, 0.7888], device='cuda:0')
# Epoch 7
# Accuracies: tensor([0.8317, 0.8322, 0.7692], device='cuda:0')
# New accuracy has been reached: 0.8274444341659546
# Epoch 8
# Accuracies: tensor([0.8481, 0.7690, 0.7979], device='cuda:0')
# Epoch 9
# Accuracies: tensor([0.8444, 0.8325, 0.7692], device='cuda:0')
# New accuracy has been reached: 0.8299999833106995
# Epoch 10
# Accuracies: tensor([0.8305, 0.8495, 0.7617], device='cuda:0')
# New accuracy has been reached: 0.839555561542511
# Epoch 11
# Accuracies: tensor([0.8493, 0.8296, 0.7662], device='cuda:0')
# Epoch 12
# Accuracies: tensor([0.8305, 0.8471, 0.7617], device='cuda:0')
# Epoch 13
# Accuracies: tensor([0.8341, 0.8263, 0.7768], device='cuda:0')
# Epoch 14
# Accuracies: tensor([0.8287, 0.8615, 0.7602], device='cuda:0')
# New accuracy has been reached: 0.8479999899864197
# Epoch 15
# Accuracies: tensor([0.8620, 0.8423, 0.7496], device='cuda:0')
# Epoch 16
# Accuracies: tensor([0.8172, 0.9071, 0.6953], device='cuda:0')
# New accuracy has been reached: 0.875
# Epoch 17
# Accuracies: tensor([0.8450, 0.8652, 0.7526], device='cuda:0')
# Epoch 18
# Accuracies: tensor([0.8378, 0.8736, 0.7285], device='cuda:0')
# Epoch 19
# Accuracies: tensor([0.8081, 0.8806, 0.7496], device='cuda:0')
# Epoch 20
# Accuracies: tensor([0.8499, 0.8727, 0.7330], device='cuda:0')
# Epoch 21
# Accuracies: tensor([0.8329, 0.8751, 0.7406], device='cuda:0')
# FOR FOLD 4, THE TEST ACCURACY WAS 0.8602222204208374
# FOR FOLD 4, THE ACCURACIES WERE tensor([0.8310, 0.8800, 0.7220], device='cuda:0')
# ---------------------------------------

# %%
for _ in range(poisson.rvs(2)):
    print(1)
# Out:
# 1
# 1
# 1
